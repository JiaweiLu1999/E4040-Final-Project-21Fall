# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import datetime
import time
import scipy.io as scio


from utils.utils import *
from utils.model import SSI_RES_UNET
from utils.train import Train_Model

# %reload_ext autoreload
# %autoreload 2

# %%
# should be 2.4.0
tf.__version__
# Out:
# '2.4.0'

# %% [markdown]
# # 1. Load training and test data

# %%
data_path = "Data/cave/"              # Training data path
test_path = "Data/testing/simu/"      # Testing path of 10 tested simulated ground truth 28 wavelenghts for HSI
patch_size = 256
short = False                         # set short=True to load smaller training set for quickly test

# %%
train_set = LoadTraining(data_path, short= True)
test_set = LoadTest(test_path, patch_size)
# Out:
# training sences: 205
# Sence 0 is loaded. scene1.mat
# Sence 1 is loaded. scene10.mat
# Sence 2 is loaded. scene100.mat
# Sence 3 is loaded. scene101.mat
# Sence 4 is loaded. scene102.mat
# Sence 5 is loaded. scene103.mat
# Sence 6 is loaded. scene104.mat
# Sence 7 is loaded. scene105.mat
# Sence 8 is loaded. scene106.mat
# Sence 9 is loaded. scene107.mat
# Sence 10 is loaded. scene108.mat
# Sence 11 is loaded. scene109.mat
# Sence 12 is loaded. scene11.mat
# Sence 13 is loaded. scene110.mat
# Sence 14 is loaded. scene111.mat
# Sence 15 is loaded. scene112.mat
# Sence 16 is loaded. scene113.mat
# Sence 17 is loaded. scene114.mat
# Sence 18 is loaded. scene115.mat
# Sence 19 is loaded. scene116.mat
# Sence 20 is loaded. scene117.mat
# Sence 21 is loaded. scene118.mat
# Sence 22 is loaded. scene119.mat
# Sence 23 is loaded. scene12.mat
# Sence 24 is loaded. scene120.mat
# Sence 25 is loaded. scene121.mat
# Sence 26 is loaded. scene122.mat
# Sence 27 is loaded. scene123.mat
# ...

# %% [markdown]
# # 2. Define Model and Train

# %%
# these two flags are set to realize different ways of training
# if both False, train a normal model
# if energy_flag = True, using energy normalization trick
# if mix_flag = True, using mix training
# if both True, apply two tricks at the same time
energy_flag = True
mix_flag = True

train_model = Train_Model(1, energy_flag, mix_flag, train_set, test_set, 'v3_mask_1')
train_model.initialize_model()
# Out:
# ========== Model Structure ==========
# Model: "ssi_res_unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_layer (InputLayer)        [(None, 29, 256, 256 0
# __________________________________________________________________________________________________
# input_conv (Conv2D)             (None, 64, 256, 256) 16768       input_layer[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 64, 258, 258) 0           input_conv[0][0]
# __________________________________________________________________________________________________
# downsampler_1 (Conv2D)          (None, 64, 128, 128) 36928       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# each epoch nearly take 5 mins
train_model.train()
# Out:
# ========== Training start ==========
# Energy Normalization Applied
# Mix Training Applied
# ===> Epoch 1 Complete: Avg. Loss: 0.086541 time: 280.15
# ===> testing psnr = 20.79, ssim = 0.561, time: 1.13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-6b5c62e8deff> in <module>
#       1 # each epoch nearly take 5 mins
# ----> 2 train_model.train()
#
# ~/4040 Project/e4040-2021Fall-Project-YZJH-ys3493-zy2501-jl5999/utils/train.py in train(self)
#     134                 mask_path = self.mask_path
#     135             mask3d_batch, mask_s = generate_masks(mask_path, self.batch_size, self.energy) #generate 3d masks
# --> 136             self.optimize(epoch, logger, mask3d_batch, mask_s)
#     137             (pred, truth, psnr_all, ssim_all, psnr_mean, ssim_mean) = self.test(epoch, logger, mask3d_batch, mask_s)
#     138
#
# ...
